# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# These data were obtained from the Exploratory Mdo
#
# Dummy Classifier: 57%
#
# TF-IDF: RF: 79 LR: 80.3 DT: 73 MNB: 80 GB: 80 svc: 80
# CV: RF: 80 LR: 80.6 DT: 73 MNB: 80 gb: 80 svc: 80

# %%
#X values
height = [57, 80, 73, 79, 80, 80, 80]
#X labels
x = ["Dummy", "Logistic Regression", "Decision Tree", "Random Forest", "Naive Bayes", "Gradient Boost", "Support Vector"]
#no idea what it does
#labels = "Genres"

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Plot vertical bars of fixed width by passing x and height values to .bar() function 
ax.bar(x, height)

# Give a title to the bar graph and label the axes
ax.set_title("Accuracy using TF-IDF", fontsize=25)

# Set labels for X and Y axes
#ax.set_xlabel("Models")
plt.xticks(rotation = 45)
ax.set_ylabel("% Accuracy", fontsize=20)
plt.show()
