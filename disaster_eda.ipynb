# %% [markdown]
# This is a baseline esploration of the data.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/test.csv")
df
# Out:
#          id keyword location  \
# 0         0     NaN      NaN
# 1         2     NaN      NaN
# 2         3     NaN      NaN
# 3         9     NaN      NaN
# 4        11     NaN      NaN
# ...     ...     ...      ...
# 3258  10861     NaN      NaN
# 3259  10865     NaN      NaN
# 3260  10868     NaN      NaN
# 3261  10874     NaN      NaN
# 3262  10875     NaN      NaN
#
#                                                    text
# 0                    Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, s...
# 2     there is a forest fire at spot pond, geese are...
# 3              Apocalypse lighting. #Spokane #wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# ...

# %% [markdown]
# Only difference between the train and test data is the target column.

# %%
tr = pd.read_csv("data/train.csv")
tr
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# ...

# %%
df.info()
#about 2/3 have location, a very few are missing keyword
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3263 non-null   int64
#  1   keyword   3237 non-null   object
#  2   location  2158 non-null   object
#  3   text      3263 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 102.1+ KB

# %%
tr.info()
#about 2/3 have location, target means disaster or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
tr['target'].value_counts(1)
#1 equals disaster, 0 = normal tweet
#mild imbalance but does not need modifications to account for the imbalance.
# Out:
# 0    0.57034
# 1    0.42966
# Name: target, dtype: float64

# %%
tr.describe()
#not helpful
# Out:
#                  id      target
# count   7613.000000  7613.00000
# mean    5441.934848     0.42966
# std     3137.116090     0.49506
# min        1.000000     0.00000
# 25%     2734.000000     0.00000
# 50%     5408.000000     0.00000
# 75%     8146.000000     1.00000
# max    10873.000000     1.00000

# %%
disaster = tr[tr['target']==1]
#['text']
not_disaster = tr[tr['target']==0]
#['text']

# %%
not_disaster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4342 entries, 15 to 7593
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        4342 non-null   int64
#  1   keyword   4323 non-null   object
#  2   location  2884 non-null   object
#  3   text      4342 non-null   object
#  4   target    4342 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 203.5+ KB

# %%
disaster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3271 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        3271 non-null   int64
#  1   keyword   3229 non-null   object
#  2   location  2196 non-null   object
#  3   text      3271 non-null   object
#  4   target    3271 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 153.3+ KB
